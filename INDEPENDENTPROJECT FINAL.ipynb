# %%
#Pick a novel interesting problem at the appropriate challenge level.Student center their data around a business case,used movie data effectively.

#Explaination
#upload the data and clean it so as to be able to do data analysis on the cleaned data structure.
#The data is on financial performance of the major companies around the globe and try and identify 
#how their profit margin compare to each other 
#and if various categories are experencing similar growth pattern, which means that there is positive correlation with each or the pattern identified is a mutually exclusive kind of trend.
#try and identify how Earning per Share compare with revenues across the various categories.
#come up with data visulations for revenues to market cap,check which industry and company has the highest ROI(Return on Investment).
#Draw insightful data interpretations from the findings obtained.
#Visualisations to be made include bargraphs, Scatter plots, Boxplots and Heatmaps.

# %%
import pandas as pd
import statistics as std
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as py

# %%
# loading the dataset
df=pd.read_csv('Financial Statements.csv', encoding='latin-1')
df
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)   Revenue  Gross Profit  \
# 0       2022     AAPL       IT               2066.94  394328.0      170782.0
# 1       2021     AAPL       IT               2913.28  365817.0      152836.0
# 2       2020     AAPL       IT               2255.97  274515.0      104956.0
# 3       2019     AAPL       IT               1304.76  260174.0       98392.0
# 4       2018     AAPL       IT                748.54  265595.0      101839.0
# ..       ...      ...      ...                   ...       ...           ...
# 156     2013     AMZN     LOGI                182.54   74452.0       20271.0
# 157     2012     AMZN     LOGI                113.63   61093.0       15122.0
# 158     2011     AMZN     LOGI                 78.72   48077.0       10789.0
# 159     2010     AMZN     LOGI                 80.79   34204.0        7643.0
# 160     2009     AMZN     LOGI                 58.24   24509.0        5531.0
#
# ...

# %%
#getting an overview summary of the dataset inclusively
df.describe(include='all')
# Out:
#             ï»¿Year Company  Category  Market Cap(in B USD)        Revenue  \
# count    161.000000      161      161            160.000000     161.000000
# unique          NaN       12        9                   NaN            NaN
# top             NaN     MSFT       IT                   NaN            NaN
# freq            NaN       15       43                   NaN            NaN
# mean    2015.608696      NaN      NaN            337.604312   75862.600758
# std        4.049960      NaN      NaN            541.102812   90786.895983
# min     2009.000000      NaN      NaN              0.040000    3326.445000
# 25%     2012.000000      NaN      NaN             41.155000   22820.400000
# 50%     2016.000000      NaN      NaN            113.140000   45992.040000
# 75%     2019.000000      NaN      NaN            357.107500   77849.000000
# max     2023.000000      NaN      NaN           2913.280000  513983.000000
#
# ...

# %%
#understanding how the data is structured interms of the data types per column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ï»¿Year                              161 non-null    int64
#  1   Company                              161 non-null    object
#  2   Category                             161 non-null    object
#  3   Market Cap(in B USD)                 160 non-null    float64
#  4   Revenue                              161 non-null    float64
#  5   Gross Profit                         161 non-null    float64
#  6   Net Income                           161 non-null    float64
#  7   Earning Per Share                    161 non-null    float64
#  8   EBITDA                               161 non-null    float64
#  9   Share Holder Equity                  161 non-null    float64
#  10  Cash Flow from Operating             161 non-null    float64
# ...

# %%
#converting Earning per share, Revenue and ROI data types from float64 to int64
df['Earning Per Share'] = df['Earning Per Share'].astype('int64')
df['Revenue'] = df['Revenue'].astype('int64')
df['ROI'] = df['ROI'].astype('int64')
df
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0       2022     AAPL       IT               2066.94   394328      170782.0
# 1       2021     AAPL       IT               2913.28   365817      152836.0
# 2       2020     AAPL       IT               2255.97   274515      104956.0
# 3       2019     AAPL       IT               1304.76   260174       98392.0
# 4       2018     AAPL       IT                748.54   265595      101839.0
# ..       ...      ...      ...                   ...      ...           ...
# 156     2013     AMZN     LOGI                182.54    74452       20271.0
# 157     2012     AMZN     LOGI                113.63    61093       15122.0
# 158     2011     AMZN     LOGI                 78.72    48077       10789.0
# 159     2010     AMZN     LOGI                 80.79    34204        7643.0
# 160     2009     AMZN     LOGI                 58.24    24509        5531.0
#
# ...

# %%
#loading the first ten rows of the dataset
df.head(10)
# Out:
#    ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0     2022     AAPL       IT               2066.94   394328      170782.0
# 1     2021     AAPL       IT               2913.28   365817      152836.0
# 2     2020     AAPL       IT               2255.97   274515      104956.0
# 3     2019     AAPL       IT               1304.76   260174       98392.0
# 4     2018     AAPL       IT                748.54   265595      101839.0
# 5     2017     AAPL       IT                868.87   229234       88186.0
# 6     2016     AAPL       IT                617.59   215639       84263.0
# 7     2015     AAPL       IT                586.86   233715       93626.0
# 8     2014     AAPL       IT                647.36   182795       70537.0
# 9     2013     AAPL       IT                504.79   170910       64304.0
#
#    Net Income  Earning Per Share    EBITDA  Share Holder Equity  ...  \
# 0     99803.0                  6  130541.0              50672.0  ...
# ...

# %%
#loading the last ten rows of the dataset
df.tail(10)
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 151     2018     AMZN     LOGI                734.42   232887       93731.0
# 152     2017     AMZN     LOGI                563.54   177866       65932.0
# 153     2016     AMZN     LOGI                356.31   135987       47722.0
# 154     2015     AMZN     LOGI                316.83   107006       35355.0
# 155     2014     AMZN     LOGI                143.70    88988       26236.0
# 156     2013     AMZN     LOGI                182.54    74452       20271.0
# 157     2012     AMZN     LOGI                113.63    61093       15122.0
# 158     2011     AMZN     LOGI                 78.72    48077       10789.0
# 159     2010     AMZN     LOGI                 80.79    34204        7643.0
# 160     2009     AMZN     LOGI                 58.24    24509        5531.0
#
#      Net Income  Earning Per Share   EBITDA  Share Holder Equity  ...  \
# ...

# %%
# Check for missing values in the entire DataFrame
missing_values = df.isnull()
print(missing_values)
# Out:
#      ï»¿Year  Company   Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0      False     False     False                 False    False         False
# 1      False     False     False                 False    False         False
# 2      False     False     False                 False    False         False
# 3      False     False     False                 False    False         False
# 4      False     False     False                 False    False         False
# ..       ...       ...       ...                   ...      ...           ...
# 156    False     False     False                 False    False         False
# 157    False     False     False                 False    False         False
# 158    False     False     False                 False    False         False
# 159    False     False     False                 False    False         False
# 160    False     False     False                 False    False         False
#
# ...

# %%
#this is to count all the Null values within the whole Dataset
df.count()
df
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0       2022     AAPL       IT               2066.94   394328      170782.0
# 1       2021     AAPL       IT               2913.28   365817      152836.0
# 2       2020     AAPL       IT               2255.97   274515      104956.0
# 3       2019     AAPL       IT               1304.76   260174       98392.0
# 4       2018     AAPL       IT                748.54   265595      101839.0
# ..       ...      ...      ...                   ...      ...           ...
# 156     2013     AMZN     LOGI                182.54    74452       20271.0
# 157     2012     AMZN     LOGI                113.63    61093       15122.0
# 158     2011     AMZN     LOGI                 78.72    48077       10789.0
# 159     2010     AMZN     LOGI                 80.79    34204        7643.0
# 160     2009     AMZN     LOGI                 58.24    24509        5531.0
#
# ...

# %%
#This is counting the Null value within the specified columns( Revenue, Earning per Share and ROI) in the dataset
df[['Revenue', 'Earning Per Share', 'ROI']].count()
# Out:
# Revenue              161
# Earning Per Share    161
# ROI                  161
# dtype: int64

# %%
# Drop null values from specific columns
cleaned_df = df.dropna(subset=['Revenue', 'Earning Per Share', 'ROI'])
cleaned_df
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0       2022     AAPL       IT               2066.94   394328      170782.0
# 1       2021     AAPL       IT               2913.28   365817      152836.0
# 2       2020     AAPL       IT               2255.97   274515      104956.0
# 3       2019     AAPL       IT               1304.76   260174       98392.0
# 4       2018     AAPL       IT                748.54   265595      101839.0
# ..       ...      ...      ...                   ...      ...           ...
# 156     2013     AMZN     LOGI                182.54    74452       20271.0
# 157     2012     AMZN     LOGI                113.63    61093       15122.0
# 158     2011     AMZN     LOGI                 78.72    48077       10789.0
# 159     2010     AMZN     LOGI                 80.79    34204        7643.0
# 160     2009     AMZN     LOGI                 58.24    24509        5531.0
#
# ...

# %%
#Before replacement
#Pivot table that just represent how per category the Revenues compare and the ROI which is return on Investment
pivot_df = pd.pivot_table(cleaned_df, index='Category', values=['Revenue', 'ROI'])
pivot_df
# Out:
#                      ROI        Revenue
# Category
# BANK            0.642857   36805.928571
# Bank            3.071429   59103.857143
# ELEC           15.103448   33694.551724
# FOOD           19.142857   24144.500000
# FinTech        10.222222   16530.555556
# Finance        -0.400000   34558.700000
# IT             24.395349  143951.209302
# LOGI            8.142857  188247.142857
# Manufacturing -11.500000   16874.071429

# %%
# Replace 'BANK' with 'Bank' in the Category column
cleaned_df['Category'] =cleaned_df['Category'].replace('BANK', 'Bank')
cleaned_df
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0       2022     AAPL       IT               2066.94   394328      170782.0
# 1       2021     AAPL       IT               2913.28   365817      152836.0
# 2       2020     AAPL       IT               2255.97   274515      104956.0
# 3       2019     AAPL       IT               1304.76   260174       98392.0
# 4       2018     AAPL       IT                748.54   265595      101839.0
# ..       ...      ...      ...                   ...      ...           ...
# 156     2013     AMZN     LOGI                182.54    74452       20271.0
# 157     2012     AMZN     LOGI                113.63    61093       15122.0
# 158     2011     AMZN     LOGI                 78.72    48077       10789.0
# 159     2010     AMZN     LOGI                 80.79    34204        7643.0
# 160     2009     AMZN     LOGI                 58.24    24509        5531.0
#
# ...

# %%
#After replacement of BANK to Bank
#Pivot table that just represent how per category the Revenues compare and the ROI which is return on Investment
pivot_cleaned_df = pd.pivot_table(cleaned_df, index='Category', values=['Revenue', 'ROI'])
pivot_cleaned_df
# Out:
#                      ROI        Revenue
# Category
# Bank            1.857143   47954.892857
# ELEC           15.103448   33694.551724
# FOOD           19.142857   24144.500000
# FinTech        10.222222   16530.555556
# Finance        -0.400000   34558.700000
# IT             24.395349  143951.209302
# LOGI            8.142857  188247.142857
# Manufacturing -11.500000   16874.071429

# %%
#Data Visualisation
#Comparing Earning Per Share, Revenue and ROI Using various graph representations

# %%
# Plot the Earning Per Shares values
#Assuming 'cleaned_df' is your DataFrame containing the Earning Per Share data
plt.figure(figsize=(8,10))
sns.barplot(x='Category', y='Earning Per Share', data=cleaned_df)
plt.xlabel('Category')
plt.ylabel('Earning Per Share')
plt.title('Earning Per Share')
plt.show()
#interpretation
#according to the bargraph finance had the worst Eearning per Share while the food category had the best Earning per Share. This means that the Earning per Share was favourable for the companies that are operating under the food cluster or category.

# %%
#Revenue Graphical representation
plt.figure(figsize=(10,6))
sns.boxplot(x='Category', y='Revenue', data=cleaned_df)
plt.xlabel('Category')
plt.ylabel('Revenue')
plt.title('Revenue')
plt.show()
#logistics seem to be having the best revenues with the highest company in that category making revenues beyond 500000, on the otherhand manufacturing and the food industry seem to be having low revenue that are concentrated between 50000 to 100000.
#the best category to invest in for revenue is companies under the logistics category.

# %%
#ROI graphical representation
plt.figure(figsize=(10, 6))
plt.plot(cleaned_df['Category'], cleaned_df['ROI'], marker='o', linestyle='-')
plt.xlabel('Category')
plt.ylabel('ROI')
plt.title('ROI Over Time')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(True) 
plt.show()
#under thisgraph what can be derived is that the finance industry has the highest rate return on investments, both from a positive angle and also negative angle, but the positive figure outweighs the negative one. for the other categories they seem to have a moderate Return on investment averaging between zero to 200 as shown by the graph.

# %%
#Scatter plot to show correlation between revenue and ROI
plt.figure(figsize=(8, 6))
plt.scatter(df['Earning Per Share'], df['Revenue'], alpha=0.5)
plt.title('Scatter Plot of Revenue vs EPS')
plt.xlabel('Earning Per Share')
plt.ylabel('Revenue')
plt.show()
# according to this graph there is positive correlation between Earning per Share and Revenue as the concetration on the value is above the zero mark.

# %%
#HeatMAP showing the relationship between the three column items
correlation_matrix = cleaned_df[['Revenue', 'ROI', 'Total Debt']].corr()

plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Heatmap Showing Relationship between Revenue, ROI and Total Debt')
plt.show()
#the heatmap shows that the three items have a positive correlation with each other meaning that one affects the other Totaldebt will affect how revenue is with a 0.22 correlation value, while roi to total debt has a rate of 0.015 which is still a positive value.

# %%
#Engineering a new feature
#Adding a debt coulmn to the financial statements dataset

# %%
#new column added-Total Debt
cleaned_df['Total Debt'] = cleaned_df['Share Holder Equity'] / cleaned_df['Debt/Equity Ratio']
cleaned_df
# Out:
#      ï»¿Year Company  Category  Market Cap(in B USD)  Revenue  Gross Profit  \
# 0       2022     AAPL       IT               2066.94   394328      170782.0
# 1       2021     AAPL       IT               2913.28   365817      152836.0
# 2       2020     AAPL       IT               2255.97   274515      104956.0
# 3       2019     AAPL       IT               1304.76   260174       98392.0
# 4       2018     AAPL       IT                748.54   265595      101839.0
# ..       ...      ...      ...                   ...      ...           ...
# 156     2013     AMZN     LOGI                182.54    74452       20271.0
# 157     2012     AMZN     LOGI                113.63    61093       15122.0
# 158     2011     AMZN     LOGI                 78.72    48077       10789.0
# 159     2010     AMZN     LOGI                 80.79    34204        7643.0
# 160     2009     AMZN     LOGI                 58.24    24509        5531.0
#
# ...

# %%
#CONCLUSION AND RECOMMENDATIONS

#The best sector to invest in as a potential investor is Information Technology. This is based on the Return on Investment that it has which stands at 24.89%.


#The company that is best for trading with as a supplier is Nvidia as it has the best current ratio which simply indicates that the company is liquid and can be able to comfortable maintain its operational costs.


#Microsoft on the other habnd would be best to invest in as a shareholder or as a potential investor due to its huge profit margins, this means that it not only has a high likelihood of paying dividends constantly but has the ability to payout high dividend rates.




#Based on revenues the logistics industry would be best to get involved with as a business person who is ;looking out for an industry which has huge revenues meaning it has good returns overall.


#Amazon being the one with the largest number of employees, this means that if the company would be liquidated then the economy would be hit hard due to the number of employees it is supporting to meet their daily livelihoods
